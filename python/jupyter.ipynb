# %%
from ftridend import *

# %%
from jupyter_tikz import TexFragment

# %%
def tikz(O):
    tikz_code = O.tikz()
    tikz = TexFragment(tikz_code)
    tikz.scale = 0.6
    return tikz.run_latex()

# %%
def display(O):
    print(O.display())

# %%
T = SchroederTree([511, 510,  494, 302, 14, 2])

# %%
T
# Out:
# [511, 510, 494, 302, 14, 2, 0]

# %%
display(T)
# Out:
# a b c d e f g h i j   012345678
# ╰─┤ │ │ │ │ │ │ │ │ = .******** = 510
#   │ │ │ ╰─┤ │ │ │ │ = .***.**** = 494
#   │ │ │   │ ╰─┴─┤ │ = .***.*..* = 302
#   │ │ │   ╰─────┴─┤ = .***..... = 14
#   │ ╰─┴───────────┤ = .*....... = 2
#   ╰───────────────┤ = ......... = 0

# %%
tikz(T)

# %%
T.left_forests_length()
# Out:
# 2

# %%
display(T.right_forest(int(2)))
# Out:
# ---- Forest ----
# a b c d e   0123
# │ │ │ │ │ = **** = 15
# ╰─┤ │ │ │ = .*** = 14
#   │ ╰─┴─┤ = .*.. = 2
# ----------------

# %%
T.left_forest?
# Out:
# Signature:      T.left_forest(*args, **kwds)
# Docstring:      Return the ith forest of the tree seen as left comb.
# Init docstring: Initialize self.  See help(type(self)) for accurate signature.
# File:
# Type:           builtin_function_or_method

# %%
T.height?
# Out:
# Signature:      T.height(*args, **kwds)
# Docstring:
# Return the height of the current SchroederTree.
#
# EXAMPLES:
#
#    >>> T = SchroederTree([511, 510,  494, 302, 14, 2])
#    >>> T.height()
#        7
# Init docstring: Initialize self.  See help(type(self)) for accurate signature.
# File:
# Type:           builtin_function_or_method

# %%
T1 = SchroederTree([7,2])

# %%
display(T1)
# Out:
# a b c d   012
# ╰─┤ ╰─┤ = .*. = 2
#   ╰───┤ = ... = 0

# %%
tikz(T1) # 1 2 1

# %%
T2 = SchroederTree([7,3,2])

# %%
tikz(T2)#2 3 1

# %%
T3=SchroederTree([7,6,2])

# %%
tikz(T3) # 1 3 2

# %%
U = SchroederTree([127,126,122,120,24,8])

# %%
tikz(U)

# %%
# Minimal cutes (angles) are : 1 3 (67)

# %% [raw]
# Possible cutes (angles) are
# empty
# 1
# 3
# (67)
# 1 3
# 1(67)
# 3 (67)
# 1 3 (67)
# (123)
# (123) (67)
# (567)
# 1 (567)
# 3 (567)
# 1 3 (567)
# (123) (567)
# (1234567)

# %%
1 3 2 6 5 4 4 ->  1 3 [2] | 6 5 4 4 ->

# %%
1 3 2 6 5 4 4 ->  [1 3 2] | 6 5 4 4 ->
