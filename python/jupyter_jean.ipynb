# %%
from ftridend import *

# %%
from jupyter_tikz import TexFragment

# %%
Ts = SchroederTree([63, 57, 56, 40])

# %%
display(Ts)
# Out:
# [63, 57, 56, 40, 0]

# %%
Ts.left_forests_length()
# Out:
# 2

# %%
display(Ts.left_forest(0))
# Out:
# [3, 3, 3, 2]

# %%
display(Ts.left_forest(1))
# Out:
# [3, 0]

# %%
def tikz(O):
    tikz_code = O.tikz()
    tikz = TexFragment(tikz_code)
    tikz.scale = 1
    return tikz.run_latex()

# %%
def display(O):
    print(O.display())

# %%
T = SchroederTree([511, 510,  494, 302, 14, 2])

# %%
T.left_forests_length()
# Out:
# 2

# %%
T.left_forest(1)
# Out:
# [0]

# %%
display(T)
# Out:
# a b c d e f g h i j   012345678
# ╰─┤ │ │ │ │ │ │ │ │ = .******** = 510
#   │ │ │ ╰─┤ │ │ │ │ = .***.**** = 494
#   │ │ │   │ ╰─┴─┤ │ = .***.*..* = 302
#   │ │ │   ╰─────┴─┤ = .***..... = 14
#   │ ╰─┴───────────┤ = .*....... = 2
#   ╰───────────────┤ = ......... = 0

# %%
tikz(T)

# %%
T.leaves()
# Out:
# 10

# %%
T.leaves?
# Out:
# Signature: T.leaves()
# Docstring: Return the number of leaves of the current SchroederTree.
# Type:      builtin_function_or_method

# %%
w = SchroederVector()

# %%
w
# Out:
# 0

# %%
w.add(T, int(7))

# %%
w
# Out:
# 7 * [511, 510, 494, 302, 14, 2, 0]

# %%
U = SchroederTree([127,100,4])
display(U)
# Out:
# a b c d e f g h   0123456
# ╰─┴─┤ ╰─┴─┤ │ │ = ..*..** = 100
#     │     ╰─┴─┤ = ..*.... = 4
#     ╰─────────┤ = ....... = 0

# %%
tikz(U)

# %%
w.add(U,int(-3))
w
# Out:
# -3 * [127, 100, 4, 0] + 7 * [511, 510, 494, 302, 14, 2, 0]

# %%
tikz(w)

# %%
S = SchroederTree([255,100,36])
print(S.right_forest(1), display(S.right_forest(1)))
tikz(S)
# Out:
# ---- Forest ----
# a
# │ =  = 0
# ----------------
#
# [0, 0] None

# %%
H = SchroederTree([255,101,100,96,0])
LF = H.left_forest(1)
display(LF)
# Out:
# ---- Forest ----
# a b c   01
# ╰─┴─┤ = .. = 0
#     │ = .. = 0
# ----------------

# %%
Te = SchroederTree([255,229,228,132,128])
print( display(Te.left_forest(int(1))), Te.right_forests_length())
tikz(Te)
# Out:
# ---- Forest ----
# a b c d e   0123
# ╰─┴─┤ │ │ = ..** = 12
#     │ │ │ = ..** = 12
#     ╰─┴─┤ = .... = 0
# ----------------
#
# None 1

# %%
Te.layer(4)
# Out:
# 128

# %%
display(SchroederTree([127, 123, 75, 3]))
# Out:
# a b c d e f g h   0123456
# │ │ ╰─┤ │ │ │ │ = **.**** = 123
# │ │   │ ╰─┴─┤ │ = **.*..* = 75
# │ │   ╰─────┴─┤ = **..... = 3
# ╰─┴───────────┤ = ....... = 0

# %%
display(T)
# Out:
# a b c d e f g h i j   012345678
# ╰─┤ │ │ │ │ │ │ │ │ = .******** = 510
#   │ │ │ ╰─┤ │ │ │ │ = .***.**** = 494
#   │ │ │   │ ╰─┴─┤ │ = .***.*..* = 302
#   │ │ │   ╰─────┴─┤ = .***..... = 14
#   │ ╰─┴───────────┤ = .*....... = 2
#   ╰───────────────┤ = ......... = 0

# %%
display(T.left_forest(0))
# Out:
# ---- Forest ----
# a b c d e f g h   0123456
# │ │ │ │ │ │ │ │ = ******* = 127
# │ │ ╰─┤ │ │ │ │ = **.**** = 123
# │ │   │ ╰─┴─┤ │ = **.*..* = 75
# │ │   ╰─────┴─┤ = **..... = 3
# ╰─┴───────────┤ = ....... = 0
# ----------------

# %%
T.right_forests_length()
# Out:
# 3

# %%
T.right_forest(2)
# Out:
# [15, 15, 14, 2]

# %%
T1 = SchroederTree([63, 57, 56, 40])

# %%
display(T1)
# Out:
# a b c d e f g   012345
# │ ╰─┴─┤ │ │ │ = *..*** = 57
# ╰─────┤ │ │ │ = ...*** = 56
#       │ ╰─┤ │ = ...*.* = 40
#       ╰───┴─┤ = ...... = 0

# %%
T2 = SchroederTree([31,30,26,2])

# %%
display(T2)
# Out:
# a b c d e f   01234
# ╰─┤ │ │ │ │ = .**** = 30
#   │ ╰─┤ │ │ = .*.** = 26
#   │   ╰─┴─┤ = .*... = 2
#   ╰───────┤ = ..... = 0

# %%
T1.left_forests_length()
# Out:
# 2

# %%
TW  = SchroederTree([127, 126, 122, 120, 24, 8])

# %%
display(TW)
# Out:
# a b c d e f g h   0123456
# ╰─┤ │ │ │ │ │ │ = .****** = 126
#   │ ╰─┤ │ │ │ │ = .*.**** = 122
#   ╰───┤ │ │ │ │ = ...**** = 120
#       │ │ ╰─┴─┤ = ...**.. = 24
#       │ ╰─────┤ = ...*... = 8
#       ╰───────┤ = ....... = 0

# %%
TW.
